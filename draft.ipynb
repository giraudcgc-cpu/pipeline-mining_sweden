# %%
import requests
import pandas as pd
import json

"""  
# --- preparation ---
url = "https://api.sgu.se/oppnadata/mineralrattigheter/ogc/features/v1/collections"

response=requests.get(url)

# ---- successful? ---
print(response.status_code)
print(response.headers.get("Content-Type"))

if response.status_code == 200:
    print("Good to go!")

    data = response.json()

else:
    print("Problem!") 
"""
# Out:
# '  \n# --- preparation ---\nurl = "https://api.sgu.se/oppnadata/mineralrattigheter/ogc/features/v1/collections"\n\nresponse=requests.get(url)\n\n# ---- successful? ---\nprint(response.status_code)\nprint(response.headers.get("Content-Type"))\n\nif response.status_code == 200:\n    print("Good to go!")\n\n    data = response.json()\n\nelse:\n    print("Problem!") \n'

# %%
""" 
# --- Before doing anything, let's check the structure ---
print(json.dumps(data, indent=2))

# note: no ID as INT but a str
"""
# Out:
# " \n# --- Before doing anything, let's check the structure ---\nprint(json.dumps(data, indent=2))\n\n# note: no ID as INT but a str\n"

# %%
""" 
# Confirming IDs and titles as per above
for coll in data["collections"]:
    print(f"{coll['id']:40}  {coll['title']}")
"""
# Out:
# ' \n# Confirming IDs and titles as epr above\nfor coll in data["collections"]:\n    print(f"{coll[\'id\']:40}  {coll[\'title\']}")\n'

# %%
# Now that I have chosen the collection, I have commented with # all the above

collection = "ut-metaller-industrimineral-beviljade"   
url = f"https://api.sgu.se/oppnadata/mineralrattigheter/ogc/features/v1/collections/{collection}/items"

params = {
    "limit": 10,
    "f": "json"    
}

response=requests.get(url)

# ---- successful? ---
print(response.status_code)

if response.status_code == 200:
    print("OK!")

else:
    print("Problem!")
# Out:
# 200
# OK!

# %%
# --- Convert to DataFrame ---
raw_data = response.json()
raw_data

# %%
# --- data info ---
print(raw_data.keys())
# Out:
# dict_keys(['type', 'features', 'numberMatched', 'numberReturned', 'timeStamp', 'links'])

# %%
# --- backup ---
import copy
raw_data_backup = copy.deepcopy(raw_data)

# %%
# --- Access direct to the data ---
df = pd.json_normalize(raw_data["features"])
df
# Out:
#         type                                          id geometry_name  \
# 0    Feature   ut-metaller-industrimineral-beviljade.101          geom
# 1    Feature  ut-metaller-industrimineral-beviljade.1082          geom
# 2    Feature  ut-metaller-industrimineral-beviljade.1106          geom
# 3    Feature  ut-metaller-industrimineral-beviljade.1107          geom
# 4    Feature  ut-metaller-industrimineral-beviljade.1153          geom
# ..       ...                                         ...           ...
# 822  Feature  ut-metaller-industrimineral-beviljade.8665          geom
# 823  Feature   ut-metaller-industrimineral-beviljade.934          geom
# 824  Feature   ut-metaller-industrimineral-beviljade.981          geom
# 825  Feature   ut-metaller-industrimineral-beviljade.985          geom
# 826  Feature    ut-metaller-industrimineral-beviljade.99          geom
#
#     geometry.type                               geometry.coordinates  \
# 0         Polygon  [[[15.62086114, 61.42015288], [15.63762983, 61...
# 1         Polygon  [[[14.22385964, 63.06965876], [14.28142836, 63...
# 2         Polygon  [[[16.96776522, 60.95131672], [17.02419227, 60...
# 3         Polygon  [[[20.67505791, 65.00541833], [20.70710205, 64...
# 4         Polygon  [[[18.61690211, 65.12937427], [18.71831282, 65...
# ..            ...                                                ...
# 822       Polygon  [[[19.16058012, 65.33874707], [19.30516653, 65...
# 823       Polygon  [[[14.56286044, 58.10941313], [14.56837542, 58...
# 824       Polygon  [[[21.23732586, 65.63296628], [21.23915964, 65...
# 825       Polygon  [[[20.43648518, 64.90956848], [20.52842996, 64...
# 826       Polygon  [[[16.52135812, 59.96840529], [16.55184512, 59...
#
#           properties.name properties.licenceid properties.diarynr  \
# 0    Kringeltjärn nr 2002              2020:75    BS 200-447-2020
# 1          Skallböle nr 1               2016:7   BS 200-1047-2015
# 2             Bergby nr 6              2021:50    BS 200-304-2021
# 3      Lillkågeträsk nr 1              2019:96    BS 200-888-2019
# 4          Ytterberg nr 2             2018:108    BS 200-449-2018
# ..                    ...                  ...                ...
# 822     Stöverberg nr 101              2026:47   BS 200-1879-2025
# 823       Norra Kärr nr 1             2009:139    BS 200-829-2009
# 824   Klöverträsk nr 1001              2020:40   BS 200-1317-2019
# 825        Björkdal nr 34             2017:162    BS 200-728-2017
# 826      Jugansbo nr 1007             2020:110    BS 200-360-2020
#
#      properties.area_ha properties.appl_date  ...  \
# 0              413.6150          2020-04-13Z  ...
# 1              783.9565          2015-10-15Z  ...
# 2             2440.5912          2021-04-22Z  ...
# 3              628.3206          2019-08-13Z  ...
# 4             1726.2657          2018-05-29Z  ...
# ..                  ...                  ...  ...
# 822          20838.5904          2025-12-30Z  ...
# 823            139.3812          2009-06-12Z  ...
# 824           1459.0196          2019-12-09Z  ...
# 825           2520.1587          2017-09-01Z  ...
# 826           1320.0703          2020-03-18Z  ...
#
#                   properties.mineral                   properties.county  \
# 0                             grafit                      Gävleborgs län
# 1                           molybden                       Jämtlands län
# 2                     litium, tantal                      Gävleborgs län
# 3    bly, guld, koppar, silver, zink                   Västerbottens län
# 4         guld, koppar, silver, zink                   Västerbottens län
# ..                               ...                                 ...
# 822  bly, guld, koppar, silver, zink  Västerbottens län, Norrbottens län
# 823                    nefelinsyenit   Östergötlands län, Jönköpings län
# 824   guld, koppar, molybden, silver                     Norrbottens län
# 825                             guld                   Västerbottens län
# 826                bly, silver, zink                    Västmanlands län
#
#                    properties.municipal  \
# 0                      Ovanåkers kommun
# 1              Åre kommun, Bergs kommun
# 2                          Gävle kommun
# 3                     Skellefteå kommun
# 4                           Malå kommun
# ..                                  ...
# 822     Malå kommun, Arvidsjaurs kommun
# 823  Ödeshögs kommun, Jönköpings kommun
# 824       Älvsbyns kommun, Piteå kommun
# 825                   Skellefteå kommun
# 826                         Sala kommun
#
#                                properties.owners properties.permitid  \
# 0                       Woxna Graphite AB (100%)                 101
# 1               Vanadis Battery Metals AB (100%)                1082
# 2                       Bergby Lithium AB (100%)                1106
# 3    Elemental Exploration Scandinavia AB (100%)                1107
# 4                               Minexp AB (100%)                1153
# ..                                           ...                 ...
# 822                        1478078 BC Ltd (100%)                8665
# 823                    GREENNA Mineral AB (100%)                 934
# 824                    Boliden Mineral AB (100%)                 981
# 825                    Björkdalsgruvan AB (100%)                 985
# 826                    Boliden Mineral AB (100%)                  99
#
#       properties.permittype properties.status properties.export_date  \
# 0    Undersökningstillstånd          Beviljad            2026-03-04Z
# 1    Undersökningstillstånd          Beviljad            2026-03-04Z
# 2    Undersökningstillstånd          Beviljad            2026-03-04Z
# 3    Undersökningstillstånd          Beviljad            2026-03-04Z
# 4    Undersökningstillstånd          Beviljad            2026-03-04Z
# ..                      ...               ...                    ...
# 822  Undersökningstillstånd          Beviljad            2026-03-04Z
# 823  Undersökningstillstånd          Beviljad            2026-03-04Z
# 824  Undersökningstillstånd          Beviljad            2026-03-04Z
# 825  Undersökningstillstånd          Beviljad            2026-03-04Z
# 826  Undersökningstillstånd          Beviljad            2026-03-04Z
#
#     properties.geom_area properties.geom_length
# 0           4.136150e+06           11940.334919
# 1           7.839565e+06           14358.080301
# 2           2.440591e+07           29847.103720
# 3           6.283206e+06           12909.319537
# 4           1.726266e+07           35705.260879
# ..                   ...                    ...
# 822         2.083859e+08           88147.766732
# 823         1.393812e+06            4821.958851
# 824         1.459020e+07           15874.834937
# 825         2.520159e+07           23341.174973
# 826         1.320070e+07           20591.821873
#
# [827 rows x 23 columns]

# %%
# --- removing columns for simplicity ---
print(df.keys())
# Out:
# Index(['type', 'id', 'geometry_name', 'geometry.type', 'geometry.coordinates',
#        'properties.name', 'properties.licenceid', 'properties.diarynr',
#        'properties.area_ha', 'properties.appl_date', 'properties.dec_date',
#        'properties.validfrom', 'properties.validto', 'properties.mineral',
#        'properties.county', 'properties.municipal', 'properties.owners',
#        'properties.permitid', 'properties.permittype', 'properties.status',
#        'properties.export_date', 'properties.geom_area',
#        'properties.geom_length'],
#       dtype='str')

# %%
removed_columns = ["type","geometry_name","geometry.type", "geometry.coordinates","properties.diarynr","properties.status",
                  "properties.export_date", "properties.geom_area", "properties.geom_length"]

df_col_ok = df.drop(columns=removed_columns)
df_col_ok
# Out:
#                                              id       properties.name  \
# 0     ut-metaller-industrimineral-beviljade.101  Kringeltjärn nr 2002
# 1    ut-metaller-industrimineral-beviljade.1082        Skallböle nr 1
# 2    ut-metaller-industrimineral-beviljade.1106           Bergby nr 6
# 3    ut-metaller-industrimineral-beviljade.1107    Lillkågeträsk nr 1
# 4    ut-metaller-industrimineral-beviljade.1153        Ytterberg nr 2
# ..                                          ...                   ...
# 822  ut-metaller-industrimineral-beviljade.8665     Stöverberg nr 101
# 823   ut-metaller-industrimineral-beviljade.934       Norra Kärr nr 1
# 824   ut-metaller-industrimineral-beviljade.981   Klöverträsk nr 1001
# 825   ut-metaller-industrimineral-beviljade.985        Björkdal nr 34
# 826    ut-metaller-industrimineral-beviljade.99      Jugansbo nr 1007
#
#     properties.licenceid  properties.area_ha properties.appl_date  \
# 0                2020:75            413.6150          2020-04-13Z
# 1                 2016:7            783.9565          2015-10-15Z
# 2                2021:50           2440.5912          2021-04-22Z
# 3                2019:96            628.3206          2019-08-13Z
# 4               2018:108           1726.2657          2018-05-29Z
# ..                   ...                 ...                  ...
# 822              2026:47          20838.5904          2025-12-30Z
# 823             2009:139            139.3812          2009-06-12Z
# 824              2020:40           1459.0196          2019-12-09Z
# 825             2017:162           2520.1587          2017-09-01Z
# 826             2020:110           1320.0703          2020-03-18Z
#
#     properties.dec_date properties.validfrom properties.validto  \
# 0           2020-11-04Z          2020-11-04Z        2026-11-04Z
# 1           2016-01-20Z          2016-01-20Z        2028-01-20Z
# 2           2021-07-06Z          2021-07-06Z        2027-07-06Z
# 3           2019-11-20Z          2019-11-20Z        2027-11-20Z
# 4           2018-09-26Z          2018-09-26Z        2026-09-26Z
# ..                  ...                  ...                ...
# 822         2026-03-04Z          2026-03-04Z        2029-03-04Z
# 823         2009-08-31Z          2009-08-31Z        2026-08-31Z
# 824         2020-04-28Z          2020-04-28Z        2028-04-28Z
# 825         2017-11-09Z          2017-11-09Z        2029-11-09Z
# 826         2020-12-16Z          2020-12-16Z        2026-12-16Z
#
#                   properties.mineral                   properties.county  \
# 0                             grafit                      Gävleborgs län
# 1                           molybden                       Jämtlands län
# 2                     litium, tantal                      Gävleborgs län
# 3    bly, guld, koppar, silver, zink                   Västerbottens län
# 4         guld, koppar, silver, zink                   Västerbottens län
# ..                               ...                                 ...
# 822  bly, guld, koppar, silver, zink  Västerbottens län, Norrbottens län
# 823                    nefelinsyenit   Östergötlands län, Jönköpings län
# 824   guld, koppar, molybden, silver                     Norrbottens län
# 825                             guld                   Västerbottens län
# 826                bly, silver, zink                    Västmanlands län
#
#                    properties.municipal  \
# 0                      Ovanåkers kommun
# 1              Åre kommun, Bergs kommun
# 2                          Gävle kommun
# 3                     Skellefteå kommun
# 4                           Malå kommun
# ..                                  ...
# 822     Malå kommun, Arvidsjaurs kommun
# 823  Ödeshögs kommun, Jönköpings kommun
# 824       Älvsbyns kommun, Piteå kommun
# 825                   Skellefteå kommun
# 826                         Sala kommun
#
#                                properties.owners properties.permitid  \
# 0                       Woxna Graphite AB (100%)                 101
# 1               Vanadis Battery Metals AB (100%)                1082
# 2                       Bergby Lithium AB (100%)                1106
# 3    Elemental Exploration Scandinavia AB (100%)                1107
# 4                               Minexp AB (100%)                1153
# ..                                           ...                 ...
# 822                        1478078 BC Ltd (100%)                8665
# 823                    GREENNA Mineral AB (100%)                 934
# 824                    Boliden Mineral AB (100%)                 981
# 825                    Björkdalsgruvan AB (100%)                 985
# 826                    Boliden Mineral AB (100%)                  99
#
#       properties.permittype
# 0    Undersökningstillstånd
# 1    Undersökningstillstånd
# 2    Undersökningstillstånd
# 3    Undersökningstillstånd
# 4    Undersökningstillstånd
# ..                      ...
# 822  Undersökningstillstånd
# 823  Undersökningstillstånd
# 824  Undersökningstillstånd
# 825  Undersökningstillstånd
# 826  Undersökningstillstånd
#
# [827 rows x 14 columns]

# %%
# --- List of the columns ---
print(list(df_col_ok.columns))
# Out:
# ['id', 'properties.name', 'properties.licenceid', 'properties.area_ha', 'properties.appl_date', 'properties.dec_date', 'properties.validfrom', 'properties.validto', 'properties.mineral', 'properties.county', 'properties.municipal', 'properties.owners', 'properties.permitid', 'properties.permittype']

# %%
# --- missing values ---
print(df_col_ok.isna().sum())
# Out:
# id                       0
# properties.name          0
# properties.licenceid     0
# properties.area_ha       0
# properties.appl_date     0
# properties.dec_date      0
# properties.validfrom     0
# properties.validto       0
# properties.mineral       0
# properties.county        0
# properties.municipal     0
# properties.owners        0
# properties.permitid      0
# properties.permittype    0
# dtype: int64

# %%
# --- QUESTIONS ----
# Top 5 counties to get their premits approved
print(df_col_ok["properties.county"].value_counts().head())
# Out:
# properties.county
# Västerbottens län    204
# Norrbottens län      203
# Dalarnas län          87
# Jämtlands län         58
# Gävleborgs län        43
# Name: count, dtype: int64

# %%
# --- The 1rst mineral ---
print(df_col_ok["properties.mineral"].value_counts().head())
# Out:
# properties.mineral
# bly, guld, koppar, silver, zink                                              108
# järn som förekommer i berggrunden                                             35
# guld, koppar, silver, zink                                                    26
# lantan och lantanider, molybden, nickel, skandium, vanadin, yttrium, zink     26
# guld, koppar                                                                  25
# Name: count, dtype: int64
